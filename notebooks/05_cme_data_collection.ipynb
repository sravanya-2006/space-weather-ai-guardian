# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanya-2006/space-weather-ai-guardian/blob/main/notebooks/05_cme_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sravanya-2006/space-weather-ai-guardian.git
# Out:
# Cloning into 'space-weather-ai-guardian'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 48 (delta 12), reused 29 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 232.51 KiB | 1.58 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# %cd space-weather-ai-guardian
# Out:
# /content/space-weather-ai-guardian

# %%
import requests
import pandas as pd
import os

# %%
API_KEY = "YOUR_API_KEY"

url = "https://api.nasa.gov/DONKI/CME"

params = {
    "startDate": "2024-01-01",
    "endDate": "2024-12-31",
    "api_key": API_KEY
}

response = requests.get(url, params=params)

data = response.json()

print("Records:", len(data))
